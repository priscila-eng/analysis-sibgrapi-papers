# %%
import requests
from bs4 import BeautifulSoup, Comment
from pathlib import Path
import os
import os.path
from os import path

# %%
url = 'http://sibgrapi.sid.inpe.br/col/sid.inpe.br/banon/2001/03.30.15.38.24/doc/mirror.cgi/About?languagebutton=en&languagerep1=sid.inpe.br/banon/2001/05.04.15.05&languagerep2=dpi.inpe.br/banon/1999/05.03.22.11&firstlanguagerep=sid.inpe.br/banon/2001/05.04.15.05&submissionformrep=dpi.inpe.br/banon-pc2@80/2006/08.30.19.42&returnbutton=yes'
req_main_page = requests.get(url)

# %%
main_page = BeautifulSoup(req_main_page.content, 'html.parser')
table = main_page.find_all('table')

# %%
def getYearConf(string):
    counter = 0
    year = ""
    for char in string:
        if char.isdigit():
            year += char
            counter += 1
        if(counter == 4):
            return year

# %%
years = []
all_links = []
for tag_a in table[0].find_all('a'):
    year = getYearConf(tag_a.text)
    link = tag_a.get('href')
    dois_pontos = ":"
    format = dois_pontos + str(year) + dois_pontos
    if year not in years and year != None:
        years.append(year)
        all_links.append(link)
    elif year in years and year != None:
        if year == '2021':
            length = len(all_links)
            all_links[length - 1] = link

# %%
confs = []
for i in range(len(years)):
    lista = [int(years[i]), all_links[i]]
    confs.append(lista)

# %%
main_pages_papers_confs = []
for conf in confs:
    req_main_page_paper = requests.get(conf[1])
    main_page_paper = BeautifulSoup(req_main_page_paper.content, 'html.parser')
    frame = main_page_paper.find_all('frame')
    yearLinks = [conf[0], frame[1].get('src')]
    main_pages_papers_confs.append(yearLinks)

# %%
def getTagsAfterComments(link):
    req_main_page_paper = requests.get(link)
    main_page_paper = BeautifulSoup(req_main_page_paper.content, 'html.parser')
    separator = "aaaaaaaaaaaa"
    comment = main_page_paper.find(string=lambda text: isinstance(text, Comment) and separator in text)
    if comment:
        next_element = comment.find_next_siblings()
        if next_element:
            return next_element
        else:
            return None

# %%
def getQtPapersCategory(html):
    countersCategory = {}
    key = ""
    counterPapers = 0
    for tag in html:
        if tag.get('class') and "titleAuthorTABLE" in tag.get('class'):
            counterPapers = counterPapers + 1
        if tag.name == "b":
            if counterPapers == 0:
                key = tag.text
            countersCategory[key] = counterPapers
            counterPapers = 0
            key = tag.text
    
    countersCategory[key] = counterPapers
    return countersCategory

# %%
def getLinksPapers(qt, html, ano):
    links_papers = {}
    counter = 0
    all_links = []
    key_html = ""
    for tag in html:
        if tag.get('class') and "titleAuthorTABLE" in tag.get('class'):
            all_links.append(tag.find('a').get('href'))
            counter = counter + 1
        if tag.name == "b":
            if counter == 0:
                key_html = tag.text
            if qt[key_html] == counter:
                links_papers[key_html] = all_links
                all_links = []
                counter = 0
            key_html = tag.text
     
    links_papers[key_html] = all_links
    for key, links in links_papers.items():
        if not "Video" in key:
            for url in links:
                url = url.split("?")
                url = url[0][5:]
                url_formatted = "http://sibgrapi.sid.inpe.br/col/" + url + "/doc/thisInformationItemHomePage.html"
                req_paper_page = requests.get(url_formatted)
                paper_page = BeautifulSoup(req_paper_page.content, 'html.parser')
                frames = paper_page.find_all("frame")
                if len(frames) > 0:
                    req_paper_PDF = requests.get(frames[1].get('src'))
                    if "@80" in url:
                        filename_formatted = str(ano) + "/" + key + "-" + url[29:39] + ".pdf"
                    elif "lotufo" in url:
                        filename_formatted = str(ano) + "/" + key + "-" + url[31:41] + ".pdf"
                    else:
                        filename_formatted = str(ano) + "/" + key + "-" + url[26:37] + ".pdf"
                    filename = Path(filename_formatted)
                    filename.write_bytes(req_paper_PDF.content)

# %%
for lista in main_pages_papers_confs:
    print("Inicia processamento do ano", lista[0])
    print("--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
    folder = "/home/priangel/Documentos/TCC/analysis-sibgrapi-papers/" + str(lista[0])
    if not path.exists(folder):
        os.mkdir(folder)
        html_links_paper = getTagsAfterComments(lista[1])
        if html_links_paper:
            qt_papers_category = getQtPapersCategory(html_links_paper)
            getLinksPapers(qt_papers_category, html_links_paper, lista[0])
        else:
            print("No links to paper")
    else:
        print(lista[0], "já processado")
        print("--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
# Out:
# Inicia processamento do ano 2022
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2022 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2021
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2021 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2020
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2020 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2019
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2019 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2018
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2018 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2017
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2017 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2016
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2016 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2015
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2015 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2014
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2014 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2013
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2013 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2012
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2012 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2011
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2011 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2010
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2010 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2009
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2009 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2008
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2008 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2007
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2007 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2006
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2006 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2005
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2005 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2004
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2004 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2003
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2003 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2002
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2002 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2001
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2001 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 2000
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 2000 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 1999
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 1999 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 1998
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 1998 já processado
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Inicia processamento do ano 1997
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# dca.fee.unicamp.br/lotufo/1997/09.15.22.16
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 10
#       8 if html_links_paper:
#       9     qt_papers_category = getQtPapersCategory(html_links_paper)
# ---> 10     getLinksPapers(qt_papers_category, html_links_paper, lista[0])
#      11 else:
#      12     print("No links to paper")
#
# Cell In[21], line 27, in getLinksPapers(qt, html, ano)
#      25 url_formatted = "http://sibgrapi.sid.inpe.br/col/" + url + "/doc/thisInformationItemHomePage.html"
#      26 req_paper_page = requests.get(url_formatted)
# ---> 27 paper_page = BeautifulSoup(req_paper_page.content, 'html.parser')
#      28 frames = paper_page.find_all("frame")
#      29 if len(frames) > 0:
#
# File ~/.local/lib/python3.10/site-packages/bs4/__init__.py:328, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     326 rejections = []
#     327 success = False
# --> 328 for (self.markup, self.original_encoding, self.declared_html_encoding,
#     329  self.contains_replacement_characters) in (
#     330      self.builder.prepare_markup(
#     331          markup, from_encoding, exclude_encodings=exclude_encodings)):
#     332     self.reset()
#     333     self.builder.initialize_soup(self)
#
# File ~/.local/lib/python3.10/site-packages/bs4/builder/_htmlparser.py:361, in HTMLParserTreeBuilder.prepare_markup(self, markup, user_specified_encoding, document_declared_encoding, exclude_encodings)
#     358 user_encodings = [document_declared_encoding]
#     360 try_encodings = [user_specified_encoding, document_declared_encoding]
# --> 361 dammit = UnicodeDammit(
#     362     markup,
#     363     known_definite_encodings=known_definite_encodings,
#     364     user_encodings=user_encodings,
#     365     is_html=True,
#     366     exclude_encodings=exclude_encodings
#     367 )
#     368 yield (dammit.markup, dammit.original_encoding,
#     369        dammit.declared_html_encoding,
#     370        dammit.contains_replacement_characters)
#
# File ~/.local/lib/python3.10/site-packages/bs4/dammit.py:601, in UnicodeDammit.__init__(self, markup, known_definite_encodings, smart_quotes_to, is_html, exclude_encodings, user_encodings, override_encodings)
#     598 self.markup = self.detector.markup
#     600 u = None
# --> 601 for encoding in self.detector.encodings:
#     602     markup = self.detector.markup
#     603     u = self._convert_from(encoding)
#
# File ~/.local/lib/python3.10/site-packages/bs4/dammit.py:442, in EncodingDetector.encodings(self)
#     439 # Use third-party character set detection to guess at the
#     440 # encoding.
#     441 if self.chardet_encoding is None:
# --> 442     self.chardet_encoding = chardet_dammit(self.markup)
#     443 if self._usable(self.chardet_encoding, tried):
#     444     yield self.chardet_encoding
#
# File ~/.local/lib/python3.10/site-packages/bs4/dammit.py:46, in chardet_dammit(s)
#      44 if isinstance(s, str):
#      45     return None
# ---> 46 return chardet_module.detect(s)['encoding']
#
# File /usr/lib/python3/dist-packages/chardet/__init__.py:41, in detect(byte_str)
#      39         byte_str = bytearray(byte_str)
#      40 detector = UniversalDetector()
# ---> 41 detector.feed(byte_str)
#      42 return detector.close()
#
# File /usr/lib/python3/dist-packages/chardet/universaldetector.py:211, in UniversalDetector.feed(self, byte_str)
#     209     self._charset_probers.append(Latin1Prober())
#     210 for prober in self._charset_probers:
# --> 211     if prober.feed(byte_str) == ProbingState.FOUND_IT:
#     212         self.result = {'encoding': prober.charset_name,
#     213                        'confidence': prober.get_confidence(),
#     214                        'language': prober.language}
#     215         self.done = True
#
# File /usr/lib/python3/dist-packages/chardet/charsetgroupprober.py:71, in CharSetGroupProber.feed(self, byte_str)
#      69 if not prober.active:
#      70     continue
# ---> 71 state = prober.feed(byte_str)
#      72 if not state:
#      73     continue
#
# File /usr/lib/python3/dist-packages/chardet/sjisprober.py:75, in SJISProber.feed(self, byte_str)
#      73             self.distribution_analyzer.feed(self._last_char, char_len)
#      74         else:
# ---> 75             self.context_analyzer.feed(byte_str[i + 1 - char_len:i + 3
#      76                                                 - char_len], char_len)
#      77             self.distribution_analyzer.feed(byte_str[i - 1:i + 1],
#      78                                             char_len)
#      80 self._last_char[0] = byte_str[-1]
#
# File /usr/lib/python3/dist-packages/chardet/jpcntx.py:156, in JapaneseContextAnalysis.feed(self, byte_str, num_bytes)
#     154 i = self._need_to_skip_char_num
#     155 while i < num_bytes:
# --> 156     order, char_len = self.get_order(byte_str[i:i + 2])
#     157     i += char_len
#     158     if i > num_bytes:
#
# KeyboardInterrupt:
